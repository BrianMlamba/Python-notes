# %% [markdown]
# #conditional statements

# %%
# as a vendor in a concert you have a target of units you should serve 
sales_target = 300
units_sold = 279
#let me compare the sales 
if units_sold >= sales_target:
    print("target achieved")
#check if we were close to target
elif units_sold >= 250 : 
    print("target almost achieved")
elif units_sold == 290:
    print("10 units left to hit target")
elif units_sold == 279: 
    print( " 279 units sold ,21 units left to hit target")
else: 
    print("target not achieved")
# Out:
# target almost achieved

# %% [markdown]
# conditional statements are statements that perform certain tasks if the condition is true and if it is false then do nothing
# you can use as many elfs as you want

# %% [markdown]
# four loops

# %%
#Use a for loop to count and print the number of scores that are above 50

# %%
#customer feedback scores
feedback_scores = (30,45.0,55.9,60,30.56,91.1,75.6,80.6,12.9)
#check if 
#print each value in the list 
for score in feedback_scores :
    print(score)
# Out:
# 30
# 45.0
# 55.9
# 60
# 30.56
# 91.1
# 75.6
# 80.6
# 12.9

# %%
print("brian")
# Out:
# brian

# %%
- for each value in sequence, perform action
    - action is indented because of the colon in the previous line 

- sequence = itereable e.g: List, Dictionary etc

- value = itereator which is the index
    - Placeholder (You can give value any name) but i is common.

# %%
for score in number_of_score :
    if score > 50:

# %%
#conditional statements for loops
for score in feedback_scores:
 #check if the score is above 50
 if score > 50:
    print(score)
# Out:
# 55.9
# 60
# 91.1
# 75.6
# 80.6
